# %%
# %run /Workspace/Users/tanmay.unhale.9@outlook.com/Instacart-Project/Ingest-Data/1-Ingest-Aisles

# %%
# %run /Workspace/Users/tanmay.unhale.9@outlook.com/Instacart-Project/Ingest-Data/2-Ingest-Departments

# %%
# %run /Workspace/Users/tanmay.unhale.9@outlook.com/Instacart-Project/Ingest-Data/3-Ingest-Orders

# %%
# %run /Workspace/Users/tanmay.unhale.9@outlook.com/Instacart-Project/Ingest-Data/4-Ingest-Products

# %%
# %run /Workspace/Users/tanmay.unhale.9@outlook.com/Instacart-Project/Ingest-Data/5-Ingest-Order-Products-Prior

# %%
# %run /Workspace/Users/tanmay.unhale.9@outlook.com/Instacart-Project/Ingest-Data/6-Ingest-Order-Products-Train
